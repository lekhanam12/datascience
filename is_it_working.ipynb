# %%
import pandas as pd

# %%
covid_df= pd.read_csv('data/district_migration.csv')
covid_df.head()
# Out:
#    lgd_state_id  lgd_district_id  inltmigrantstotal  inltmigrationrate  \
# 0             1                1          8185802.0           0.003257
# 1             1                2          8185802.0           0.001551
# 2             1                3          8185802.0           0.003776
# 3             1                4          8185802.0           0.001203
# 4             1                5          8185802.0           0.005552
#
#    inltmigrationshare  instmigrantstotal  instmigrationrate  \
# 0            0.000429         10900000.0           0.000427
# 1            0.000143         10900000.0           0.001404
# 2            0.000465         10900000.0           0.000195
# 3            0.000060         10900000.0           0.000942
# 4            0.001038         10900000.0           0.015447
#
#    instmigrationshare  outltmigrantstotal  outltmigrationrate  \
# 0            0.000042             8185802            0.001612
# ...
