# %% [markdown]
# # India - Shape Files

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import geopandas as gpd
import palettable as pltt
from seaborn import palplot

# %% [markdown]
# ## Administration Level 1 - State Level

# %%
adm1 = gpd.read_file('data/IND_adm1.shp')
f, ax = plt.subplots(1, figsize=(12, 12))
adm1.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Administration Level 2 - District Level

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
adm2 = gpd.read_file('data/IND_adm2.shp')
adm2.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Administration Level 3 - Village Level ('Taluk')

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
adm3 = gpd.read_file('data/IND_adm3.shp')
adm3.plot(ax=ax)
# Out:
# <AxesSubplot:>
