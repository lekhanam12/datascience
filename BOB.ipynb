# %%
import pandas as pd
df = pd.read_csv('data/district_migration.csv',delimiter=',')

# %%
df
# Out:
#      lgd_state_id  lgd_district_id  inltmigrantstotal  inltmigrationrate  \
# 0               1                1          8185802.0           0.003257
# 1               1                2          8185802.0           0.001551
# 2               1                3          8185802.0           0.003776
# 3               1                4          8185802.0           0.001203
# 4               1                5          8185802.0           0.005552
# ..            ...              ...                ...                ...
# 726            36              700          8185802.0           0.014595
# 727            36              720          8185802.0           0.002948
# 728            36              721          8185802.0           0.001635
# 729            37                6          8185802.0           0.000433
# 730            37                9          8185802.0           0.000427
#
#      inltmigrationshare  instmigrantstotal  instmigrationrate  \
# ...
